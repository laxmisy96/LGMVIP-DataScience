# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmisy96/LGMVIP-DataScience/blob/main/Task1_1_Iris_Flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LETSGROWMORE-VIRTUAL INTERNSHIP PROGRAM [LGMVIP]
#
# ![Screenshot (4).png](data:image/png;base64,...)
#
# # By- LAXMI S YADAHALLI
#
# BATCH-October 2021
#
# Domain-Data Science
#
# Task 1
#
# Level- Beginner

# %% [markdown]
# **DESCRIPTION OF TASK**
#
# *This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.*
#
# ![Screenshot (2).png](data:image/png;base64,...)

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn import datasets
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f8e28e4e-801f-42d0-b095-2fdb20124876" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8e28e4e-801f-42d0-b095-2fdb20124876">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# **Data Exploration**

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.057333           3.758000          1.199333
# std             0.828066          0.435866           1.765298          0.762238
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %% [markdown]
# **Data Vizualization**

# %%
sns.histplot(iris_df["sepal length (cm)"],bins=15,color='r')

# %%
sns.histplot(iris_df["petal length (cm)"],bins=15,color='g')

# %%
sns.histplot(iris_df["sepal width (cm)"],bins=10,color='b')

# %%
sns.histplot(iris_df["petal length (cm)"],bins=10,color='c')

# %%
sns.jointplot(x="sepal length (cm)", y="sepal width (cm)", data= iris_df,color='b')

# %%
sns.jointplot(x="petal length (cm)", y="petal width (cm)", data= iris_df,color='g')

# %% [markdown]
# **Data PairPlot**

# %%
sns.pairplot(iris_df)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
x = iris_df.iloc[:, [0, 1, 2, 3]].values
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(iris_df)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Making **CLUSTERS**

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state =0)
y_kmeans = kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'black', label = 'Centroids')
plt.legend()

# %% [markdown]
# # **THANKYOU**
#
# ## **Comment your suggestions**
