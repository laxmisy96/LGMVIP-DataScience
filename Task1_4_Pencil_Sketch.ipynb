# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmisy96/LGMVIP-DataScience/blob/main/Task1_4_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LETSGROWMORE-VIRTUAL INTERNSHIP PROGRAM [LGMVIP]
#
# ![Screenshot (5).png](data:image/png;base64,...)
#
#
# By- LAXMI S YADAHALLI
#
# BATCH-October 2021
#
# Domain-Data Science
#
# Task 4
#
# IMAGE TO PENCIL SKETCH CONVERSION
#
# ![Screenshot (7).png](data:image/png;base64,...)
#
# Level- Beginner

# %% [markdown]
# **Importing required libraries**

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
#  **LOADING THE IMAGE**

# %%
image=cv2.imread("/content/puppy-1903313__340.jpg",cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=510x340 at 0x7F267B586990>

# %% [markdown]
# **CONVERTING THE IMAGE INTO GRAY SCALE IMAGE**

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=510x340 at 0x7F267B59E990>

# %% [markdown]
# **Converting image into gray scale will give us black and white pixel which is required for converting the iamge into pencil sketch**

# %% [markdown]
# **INVERTING THE IMAGE**

# %%
image_invert = cv2.bitwise_not(image_gray)
cv2_imshow(image_invert)
#invert_image=255-grey_image
# Out:
# <PIL.Image.Image image mode=L size=510x340 at 0x7F267B585190>

# %% [markdown]
# **Used bit_not function to find the brighter and the lighter part in the image so that we can find the edge to create the pencil sketch**

# %% [markdown]
# **APPLYING SMOOTHING TO THE INVERTED IMAGE**

# %%
image_smoothing = cv2.GaussianBlur(image_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=510x340 at 0x7F267B583D90>

# %% [markdown]
# **By Smoothing the image we cxan reduce  the noice and find the lines to create a sketch**

# %% [markdown]
# **FUNCTION FOR GEETING THE PENCIL SKETCH**

# %%
def dogV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dogV2(image_gray, image_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=510x340 at 0x7F267B5FAE50>

# %% [markdown]
# # A PENCIL SKETCH OF GIVEN IMAGE HAS BEEN OBTAINED

# %% [markdown]
# # **THANKYOU**
